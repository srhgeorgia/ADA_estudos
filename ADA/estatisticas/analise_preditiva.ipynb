# %% [markdown]
# # 🧠 Exemplos de Análise Preditiva em Python
# ### Tipos de Amostragem:
# - Aleatória Simples
# - Estratificada
# - Sistemática
# - Por Conglomerado
#
# Cada exemplo abaixo contém uma explicação e um código correspondente.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1️⃣ Amostragem Aleatória Simples
# Cada elemento da população tem **a mesma probabilidade de ser escolhido**.

# %%
dados = pd.DataFrame({
    'idade': np.random.randint(18, 70, 1000),
    'salario': np.random.randint(1500, 10000, 1000)
})

amostra_simples = dados.sample(frac=0.1, random_state=42)
print(amostra_simples.head())
# Out:
#      idade  salario
# 521     54     8778
# 737     24     7315
# 740     41     1640
# 660     48     6433
# 411     67     2783

# %% [markdown]
# ## 2️⃣ Amostragem Estratificada
# A população é dividida em **estratos (grupos homogêneos)** e a amostragem é proporcional em cada grupo.

# %%
dados['genero'] = np.random.choice(['Masculino', 'Feminino'], 1000)

train, test = train_test_split(dados, test_size=0.2, stratify=dados['genero'], random_state=42)

print('Proporções no treino:')
print(train['genero'].value_counts(normalize=True))
print('Proporções no teste:')
print(test['genero'].value_counts(normalize=True))
# Out:
# Proporções no treino:
# genero
# Masculino    0.52375
# Feminino     0.47625
# Name: proportion, dtype: float64
# Proporções no teste:
# genero
# Masculino    0.525
# Feminino     0.475
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3️⃣ Amostragem Sistemática
# Seleciona um elemento inicial aleatório e, a partir dele, **escolhe-se cada k-ésimo elemento**.

# %%
k = 10
inicio = np.random.randint(0, k)
amostra_sistematica = dados.iloc[inicio::k]

print(amostra_sistematica.head())
print(f'Tamanho da amostra sistemática: {len(amostra_sistematica)}')
# Out:
#     idade  salario     genero
# 8      60     1980  Masculino
# 18     28     5305   Feminino
# 28     50     7895  Masculino
# 38     20     2510   Feminino
# 48     20     1727  Masculino
# Tamanho da amostra sistemática: 100

# %% [markdown]
# ## 4️⃣ Amostragem por Conglomerado
# A população é dividida em **grupos heterogêneos (conglomerados)** e alguns grupos inteiros são sorteados.

# %%
dados['filial'] = np.random.choice(['Sul', 'Sudeste', 'Centro-Oeste', 'Norte', 'Nordeste'], 1000)

filiais_sorteadas = np.random.choice(dados['filial'].unique(), 2, replace=False)
amostra_conglomerado = dados[dados['filial'].isin(filiais_sorteadas)]

print(f'Filiais escolhidas: {filiais_sorteadas}')
print(amostra_conglomerado.head())
print(f'Tamanho da amostra por conglomerado: {len(amostra_conglomerado)}')
# Out:
# Filiais escolhidas: ['Sul' 'Nordeste']
#     idade  salario     genero    filial
# 0      28     9814   Feminino       Sul
# 1      49     5064  Masculino  Nordeste
# 8      60     1980  Masculino  Nordeste
# 9      32     2211  Masculino       Sul
# 11     56     4232  Masculino  Nordeste
# Tamanho da amostra por conglomerado: 398

# %% [markdown]
# ### 💬 Observação Final
# Esses tipos de amostragem são usados antes do **treinamento de modelos preditivos**, garantindo representatividade e evitando vieses.
